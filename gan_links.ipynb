# %%
# https://www.kaggle.com/code/nageshsingh/generate-realistic-human-face-using-gan

# %%
# https://www.google.com/search?q=python+progress+bar+nedir&oq=python+progress+bar+nedir&gs_lcrp=EgZjaHJvbWUyBggAEEUYOTIKCAEQABiABBiiBDIKCAIQABiABBiiBDIKCAMQABiABBiiBNIBCDg4NjFqMGoxqAIAsAIA&sourceid=chrome&ie=UTF-8

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

from matplotlib import pyplot as plt

from tqdm import tqdm
from PIL import Image as Img
from keras import Input
from keras.layers import Dense, Reshape, LeakyReLU, Conv2D, Conv2DTranspose, Flatten, Dropout
from keras.models import Model
from keras.optimizers import RMSprop

# %%
# https://www.kaggle.com/code/cybersimar08/generate-realistic-human-face-using-gan

# %%
# https://devhunteryz.wordpress.com/2018/09/01/uretken-dusman-aglarigan-icin-yeni-baslayanlar-kilavuzu/

# %%
# https://www.theaidream.com/post/generate-realistic-human-face-using-gan-1

# %%
# https://www.kaggle.com/code/farzadnekouei/photorealistic-face-generation-using-dcgans#Step-3-|-Define-DCGAN-Architecture

# %%
# https://github.com/FarzadNekouee/DCGAN-Photorealistic-Face-Generator/blob/master/photorealistic-face-generation-using-dcgans.ipynb

# %%
#fake videos
# https://www.kaggle.com/code/gpreda/deepfake-starter-kit/notebook
